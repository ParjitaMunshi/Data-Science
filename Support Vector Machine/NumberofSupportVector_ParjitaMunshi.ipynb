# %%
import numpy as np
import pandas as pd

# %%
x = np.random.normal(size=1000)
y = np.random.normal(size=1000)

# %%
data = pd.DataFrame(
    {
        "x" : x,
        "y" : y,
        "z" : x+y>0
    }
)
print(data)
# Out:
#             x         y      z
# 0    1.235007 -0.182056   True
# 1   -0.118022  1.377157   True
# 2   -2.809356  0.647387  False
# 3   -0.552022 -2.305948  False
# 4   -1.298078  1.001370  False
# ..        ...       ...    ...
# 995  1.087813  0.001714   True
# 996 -0.452566  0.142392  False
# 997 -0.410574  1.542147   True
# 998  1.098209  0.016790   True
# 999  0.471791  0.549150   True
#
# [1000 rows x 3 columns]

# %%
data.shape
# Out:
# (1000, 3)

# %%
data.head()
# Out:
#           x         y      z
# 0  1.235007 -0.182056   True
# 1 -0.118022  1.377157   True
# 2 -2.809356  0.647387  False
# 3 -0.552022 -2.305948  False
# 4 -1.298078  1.001370  False

# %%
x = data[["x","y"]]
y = data["z"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[101   0]
#  [  4  95]]
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98       101
#         True       1.00      0.96      0.98        99
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear', degree=8)
svclassifier.fit(X_train, y_train)
# Out:
# SVC(degree=8, kernel='linear')

# %%
import matplotlib.pyplot as plt

plt.scatter(x["x"], x["y"], c=y,s=30, cmap=plt.cm.Paired)
plt.show()

# %%
from sklearn import svm
svc = svm.SVC(kernel ='linear')
svc.fit(X_train,y_train)
plt.scatter(x["x"], x["y"], c=y,s=30, cmap=plt.cm.Paired)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0],xlim[1],30)
yy = np.linspace(ylim[0],ylim[1],30)

yy,xx = np.meshgrid(yy,xx)
xy = np.vstack([xx.ravel(),yy.ravel()]).T
z= svc.decision_function(xy).reshape(xx.shape)


ax.contour(xx,yy,z,colors='k',levels= [-1,0,1],
           alpha=0.5,
           linestyles=['--','-','--'])

#plot support vectors
ax.scatter(svc.support_vectors_[:,0],
          svc.support_vectors_[:,1],
          s=100,
          linewidth=1,facecolors='none')
plt.show()
# Out:
# C:\Users\parjita\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn import svm
svc = svm.SVC(kernel ='linear',C = 10)
svc.fit(X_train,y_train)
plt.scatter(x["x"], x["y"], c=y,s=30, cmap=plt.cm.Paired)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0],xlim[1],30)
yy = np.linspace(ylim[0],ylim[1],30)

yy,xx = np.meshgrid(yy,xx)
xy = np.vstack([xx.ravel(),yy.ravel()]).T
z= svc.decision_function(xy).reshape(xx.shape)


ax.contour(xx,yy,z,colors='k',levels= [-1,0,1],
           alpha=0.5,
           linestyles=['--','-','--'])

#plot support vectors
ax.scatter(svc.support_vectors_[:,0],
          svc.support_vectors_[:,1],
          s=100,
          linewidth=1,facecolors='none')
plt.show()
# Out:
# C:\Users\parjita\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn import svm
svc = svm.SVC(kernel ='linear',C=0.1)
svc.fit(X_train,y_train)
plt.scatter(x["x"], x["y"], c=y,s=30, cmap=plt.cm.Paired)

ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0],xlim[1],30)
yy = np.linspace(ylim[0],ylim[1],30)

yy,xx = np.meshgrid(yy,xx)
xy = np.vstack([xx.ravel(),yy.ravel()]).T
z= svc.decision_function(xy).reshape(xx.shape)


ax.contour(xx,yy,z,colors='k',levels= [-1,0,1],
           alpha=0.5,
           linestyles=['--','-','--'])

#plot support vectors
ax.scatter(svc.support_vectors_[:,0],
          svc.support_vectors_[:,1],
          s=100,
          linewidth=1,facecolors='none')
plt.show()
# Out:
# C:\Users\parjita\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
